# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data/weather.csv',parse_dates=['Date/Time'],dayfirst=True,index_col='Date/Time')
df.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 01:00:00',
#                '2012-01-01 02:00:00', '2012-01-01 03:00:00',
#                '2012-01-01 04:00:00', '2012-01-01 05:00:00',
#                '2012-01-01 06:00:00', '2012-01-01 07:00:00',
#                '2012-01-01 08:00:00', '2012-01-01 09:00:00',
#                ...
#                '2012-12-31 14:00:00', '2012-12-31 15:00:00',
#                '2012-12-31 16:00:00', '2012-12-31 17:00:00',
#                '2012-12-31 18:00:00', '2012-12-31 19:00:00',
#                '2012-12-31 20:00:00', '2012-12-31 21:00:00',
#                '2012-12-31 22:00:00', '2012-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=8784, freq=None)

# %%
df.index.year # since our index is based on Datetime
# Out:
# Int64Index([2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012,
#             ...
#             2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012],
#            dtype='int64', name='Date/Time', length=8784)

# %%
df['Temp (C)']
# Out:
# Date/Time
# 2012-01-01 00:00:00   -1.8
# 2012-01-01 01:00:00   -1.8
# 2012-01-01 02:00:00   -1.8
# 2012-01-01 03:00:00   -1.5
# 2012-01-01 04:00:00   -1.5
#                       ...
# 2012-12-31 19:00:00    0.1
# 2012-12-31 20:00:00    0.2
# 2012-12-31 21:00:00   -0.5
# 2012-12-31 22:00:00   -0.2
# 2012-12-31 23:00:00    0.0
# Name: Temp (C), Length: 8784, dtype: float64

# %%
df['Temp (C)'].tolist() # if u want a list of values of column (stupidity)
# Out:
# [-1.8,
#  -1.8,
#  -1.8,
#  -1.5,
#  -1.5,
#  -1.4,
#  -1.5,
#  -1.4,
#  -1.4,
#  -1.3,
#  -1.0,
#  -0.5,
#  -0.2,
#  0.2,
#  0.8,
#  1.8,
#  2.6,
#  3.0,
#  3.8,
#  3.1,
#  3.2,
#  4.0,
#  4.4,
#  5.3,
#  5.2,
#  4.6,
#  3.9,
#  3.7,
#  2.9,
#  2.6,
#  2.3,
#  2.0,
#  1.9,
#  1.8,
#  1.5,
#  2.2,
#  1.7,
#  1.1,
#  1.1,
#  0.0,
#  -0.7,
#  -2.1,
#  -4.1,
#  -4.8,
#  -5.6,
#  -5.8,
#  -7.0,
#  -7.4,
#  -9.0,
#  -9.7,
#  -10.5,
#  -11.3,
#  -12.6,
#  -12.9,
#  -13.3,
#  -14.0,
#  -14.8,
#  -15.0,
#  -15.3,
#  -14.9,
#  -14.9,
#  -15.1,
#  -14.9,
#  -14.8,
#  -15.3,
#  -15.8,
#  -16.3,
#  -16.9,
#  -17.3,
#  -17.0,
#  -17.1,
#  -17.3,
#  -17.5,
#  -17.9,
#  -18.1,
#  -18.5,
#  -18.5,
#  -18.6,
#  -18.5,
#  -18.2,
#  -17.8,
#  -16.8,
#  -15.2,
#  -14.2,
#  -13.7,
#  -12.4,
#  -11.3,
#  -10.2,
#  -9.4,
#  -8.9,
#  -8.9,
#  -8.4,
#  -7.8,
#  -7.6,
#  -9.5,
#  -9.6,
#  -8.8,
#  -7.5,
#  -5.4,
#  -5.0,
#  -4.1,
#  -7.0,
#  -8.2,
#  -7.1,
#  -6.1,
#  -6.6,
#  -6.0,
#  -5.6,
#  -4.7,
# ...

# %%
df['Rel Hum (%)']
# Out:
# Date/Time
# 2012-01-01 00:00:00    86
# 2012-01-01 01:00:00    87
# 2012-01-01 02:00:00    89
# 2012-01-01 03:00:00    88
# 2012-01-01 04:00:00    88
#                        ..
# 2012-12-31 19:00:00    81
# 2012-12-31 20:00:00    83
# 2012-12-31 21:00:00    93
# 2012-12-31 22:00:00    89
# 2012-12-31 23:00:00    86
# Name: Rel Hum (%), Length: 8784, dtype: int64

# %%
df['Dew Point Temp (C)'].head()
# Out:
# Date/Time
# 2012-01-01 00:00:00   -3.9
# 2012-01-01 01:00:00   -3.7
# 2012-01-01 02:00:00   -3.4
# 2012-01-01 03:00:00   -3.2
# 2012-01-01 04:00:00   -3.3
# Name: Dew Point Temp (C), dtype: float64

# %%
df[['Temp (C)','Weather']]
# Out:
#                      Temp (C)               Weather
# Date/Time
# 2012-01-01 00:00:00      -1.8                   Fog
# 2012-01-01 01:00:00      -1.8                   Fog
# 2012-01-01 02:00:00      -1.8  Freezing Drizzle,Fog
# 2012-01-01 03:00:00      -1.5  Freezing Drizzle,Fog
# 2012-01-01 04:00:00      -1.5                   Fog
# ...                       ...                   ...
# 2012-12-31 19:00:00       0.1                  Snow
# 2012-12-31 20:00:00       0.2                  Snow
# 2012-12-31 21:00:00      -0.5                  Snow
# 2012-12-31 22:00:00      -0.2                  Snow
# 2012-12-31 23:00:00       0.0                  Snow
#
# [8784 rows x 2 columns]

# %%
cols = ['Temp (C)','Visibility (km)','Weather']
df[cols]
# Out:
#                      Temp (C)  Visibility (km)               Weather
# Date/Time
# 2012-01-01 00:00:00      -1.8              8.0                   Fog
# 2012-01-01 01:00:00      -1.8              8.0                   Fog
# 2012-01-01 02:00:00      -1.8              4.0  Freezing Drizzle,Fog
# 2012-01-01 03:00:00      -1.5              4.0  Freezing Drizzle,Fog
# 2012-01-01 04:00:00      -1.5              4.8                   Fog
# ...                       ...              ...                   ...
# 2012-12-31 19:00:00       0.1              9.7                  Snow
# 2012-12-31 20:00:00       0.2              9.7                  Snow
# 2012-12-31 21:00:00      -0.5              4.8                  Snow
# 2012-12-31 22:00:00      -0.2              9.7                  Snow
# 2012-12-31 23:00:00       0.0             11.3                  Snow
#
# [8784 rows x 3 columns]

# %%
df['Temp (C)'].max()
# Out:
# 33.0

# %%
df['Temp (C)'].min()
# Out:
# -23.3

# %%
df['Temp (C)'].mean()
# Out:
# 8.798144353369764

# %%
df['Temp (C)'].std()
# Out:
# 11.687882769691276

# %%
df['Temp (C)'].sum()
# Out:
# 77282.90000000001

# %% [markdown]
# ## row selection

# %%
df['Temp (C)'].plot()
# Out:
# <AxesSubplot:xlabel='Date/Time'>

# %%
df['Temp (C)'].plot(figsize=(25,7))
# Out:
# <AxesSubplot:xlabel='Date/Time'>

# %%
df['Temp (C)'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %%
df.head(10)
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# 2012-01-01 05:00:00      -1.4                -3.3           87
# 2012-01-01 06:00:00      -1.5                -3.1           89
# 2012-01-01 07:00:00      -1.4                -3.6           85
# 2012-01-01 08:00:00      -1.4                -3.6           85
# 2012-01-01 09:00:00      -1.3                -3.1           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# ...

# %%
df.tail(10)
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-12-31 14:00:00      -3.4                -5.7           84
# 2012-12-31 15:00:00      -2.3                -4.6           84
# 2012-12-31 16:00:00      -1.4                -4.0           82
# 2012-12-31 17:00:00      -1.1                -3.3           85
# 2012-12-31 18:00:00      -1.3                -3.1           88
# 2012-12-31 19:00:00       0.1                -2.7           81
# 2012-12-31 20:00:00       0.2                -2.4           83
# 2012-12-31 21:00:00      -0.5                -1.5           93
# 2012-12-31 22:00:00      -0.2                -1.8           89
# 2012-12-31 23:00:00       0.0                -2.1           86
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# Date/Time
# 2012-12-31 14:00:00                6             11.3           100.57    Snow
# 2012-12-31 15:00:00                9              9.7           100.47    Snow
# ...

# %%
df['Temp (C)'].head()
# Out:
# Date/Time
# 2012-01-01 00:00:00   -1.8
# 2012-01-01 01:00:00   -1.8
# 2012-01-01 02:00:00   -1.8
# 2012-01-01 03:00:00   -1.5
# 2012-01-01 04:00:00   -1.5
# Name: Temp (C), dtype: float64

# %%
df.head()['Temp (C)']
# Out:
# Date/Time
# 2012-01-01 00:00:00   -1.8
# 2012-01-01 01:00:00   -1.8
# 2012-01-01 02:00:00   -1.8
# 2012-01-01 03:00:00   -1.5
# 2012-01-01 04:00:00   -1.5
# Name: Temp (C), dtype: float64

# %%
df[1] # now a row number
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-a483b96b151a> in <module>
# ...

# %%
df.iloc[0] # index 0
# Out:
# Temp (C)                -1.8
# Dew Point Temp (C)      -3.9
# Rel Hum (%)               86
# Wind Spd (km/h)            4
# Visibility (km)          8.0
# Stn Press (kPa)       101.24
# Weather                  Fog
# Name: 2012-01-01 00:00:00, dtype: object

# %%
df.iloc[2322] # index 0
# Out:
# Temp (C)                        7.3
# Dew Point Temp (C)            -11.6
# Rel Hum (%)                      25
# Wind Spd (km/h)                  19
# Visibility (km)                25.0
# Stn Press (kPa)              101.16
# Weather               Mostly Cloudy
# Name: 2012-04-06 18:00:00, dtype: object

# %%
df.iloc[2322] # index 0
# Out:
# Temp (C)                        7.3
# Dew Point Temp (C)            -11.6
# Rel Hum (%)                      25
# Wind Spd (km/h)                  19
# Visibility (km)                25.0
# Stn Press (kPa)              101.16
# Weather               Mostly Cloudy
# Name: 2012-04-06 18:00:00, dtype: object

# %%
df[200:500] # slice
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-09 08:00:00      -5.9               -10.5           70
# 2012-01-09 09:00:00      -5.4                -9.2           75
# 2012-01-09 10:00:00      -4.8                -8.3           76
# 2012-01-09 11:00:00      -3.7                -7.2           77
# 2012-01-09 12:00:00      -2.5                -6.6           73
# ...                       ...                 ...          ...
# 2012-01-21 15:00:00     -11.8               -18.9           56
# 2012-01-21 16:00:00     -11.6               -18.8           55
# 2012-01-21 17:00:00     -12.1               -19.8           53
# 2012-01-21 18:00:00     -13.0               -20.2           55
# 2012-01-21 19:00:00     -13.4               -19.9           58
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# Date/Time
# 2012-01-09 08:00:00               13             16.1           101.74    Snow
# ...

# %%
df.iloc[200:500] # slice (better)
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-09 08:00:00      -5.9               -10.5           70
# 2012-01-09 09:00:00      -5.4                -9.2           75
# 2012-01-09 10:00:00      -4.8                -8.3           76
# 2012-01-09 11:00:00      -3.7                -7.2           77
# 2012-01-09 12:00:00      -2.5                -6.6           73
# ...                       ...                 ...          ...
# 2012-01-21 15:00:00     -11.8               -18.9           56
# 2012-01-21 16:00:00     -11.6               -18.8           55
# 2012-01-21 17:00:00     -12.1               -19.8           53
# 2012-01-21 18:00:00     -13.0               -20.2           55
# 2012-01-21 19:00:00     -13.4               -19.9           58
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# Date/Time
# 2012-01-09 08:00:00               13             16.1           101.74    Snow
# ...

# %%
df.iloc[:200,[0,1,2,3]]  # :200 => first 200 rows and [0,1,2,3] => col indexes in dataframe
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# ...                       ...                 ...          ...
# 2012-01-09 03:00:00      -8.8               -13.2           70
# 2012-01-09 04:00:00      -8.5               -13.2           69
# 2012-01-09 05:00:00      -8.4               -12.7           71
# 2012-01-09 06:00:00      -7.7               -11.9           72
# 2012-01-09 07:00:00      -6.8               -11.0           72
#
#                      Wind Spd (km/h)
# Date/Time
# 2012-01-01 00:00:00                4
# 2012-01-01 01:00:00                4
# 2012-01-01 02:00:00                7
# ...

# %%
df.iloc[:200,[0,1,2,3]].T
# Out:
# Date/Time           2012-01-01 00:00:00  2012-01-01 01:00:00  \
# Temp (C)                           -1.8                 -1.8
# Dew Point Temp (C)                 -3.9                 -3.7
# Rel Hum (%)                        86.0                 87.0
# Wind Spd (km/h)                     4.0                  4.0
#
# Date/Time           2012-01-01 02:00:00  2012-01-01 03:00:00  \
# Temp (C)                           -1.8                 -1.5
# Dew Point Temp (C)                 -3.4                 -3.2
# Rel Hum (%)                        89.0                 88.0
# Wind Spd (km/h)                     7.0                  6.0
#
# Date/Time           2012-01-01 04:00:00  2012-01-01 05:00:00  \
# Temp (C)                           -1.5                 -1.4
# Dew Point Temp (C)                 -3.3                 -3.3
# Rel Hum (%)                        88.0                 87.0
# Wind Spd (km/h)                     7.0                  9.0
#
# ...
